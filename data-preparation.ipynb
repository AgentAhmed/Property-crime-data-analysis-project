# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import json

# %% [markdown]
# # Crime data

# %%
crime_data = pd.read_csv('Crimes_-_2019.csv', sep=',', header=0)

# %% [markdown]
# Next we remove rows with no location information and change the type of the date column.

# %%
crime_data = crime_data[crime_data.Latitude.notnull()]
crime_data.Date = pd.to_datetime(crime_data.Date)

# %%
crime_data.head()
# Out:
#           ID Case Number                Date                Block  IUCR  \
# 11  12098557    JD288415 2019-02-01 00:01:00      025XX W 50TH ST  0460
# 22  12082526    JD269406 2019-09-24 12:00:00  050XX N KENMORE AVE  1153
# 25  11859264    JC470909 2019-10-13 06:40:00   012XX S KARLOV AVE  1310
# 35  11662417    JC232642 2019-04-21 12:30:00      009XX E 80TH ST  031A
# 39  12990873    JG161829 2019-08-17 13:14:00   008XX N KARLOV AVE  1751
#
#                   Primary Type                             Description  \
# 11                     BATTERY                                  SIMPLE
# 22          DECEPTIVE PRACTICE     FINANCIAL IDENTITY THEFT OVER $ 300
# 25             CRIMINAL DAMAGE                             TO PROPERTY
# 35                     ROBBERY                         ARMED - HANDGUN
# 39  OFFENSE INVOLVING CHILDREN  CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
#
#    Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 11            RESIDENCE   False      True  ...  14.0              63
# 22            RESIDENCE   False     False  ...  48.0               3
# 25            APARTMENT   False      True  ...  24.0              29
# 35            RESIDENCE   False     False  ...   8.0              44
# 39            RESIDENCE    True      True  ...  37.0              23
#
#     FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 11       08B     1160373.0    1871438.0  2019  07/09/2020 03:44:39 PM
# 22        11     1168334.0    1933969.0  2019  06/24/2020 03:40:28 PM
# 25        14     1149246.0    1894056.0  2019  10/20/2019 07:09:58 PM
# 35        03     1184044.0    1852159.0  2019  09/14/2023 03:41:59 PM
# 39        17     1148899.0    1905351.0  2019  09/14/2023 03:41:59 PM
#
#      Latitude  Longitude                       Location
# 11  41.802925 -87.687367  (41.802924631, -87.687367104)
# 22  41.974346 -87.656361  (41.974346203, -87.656361214)
# 25  41.865214 -87.727590  (41.865213688, -87.727590376)
# 35  41.749500 -87.601157    (41.749500329, -87.6011574)
# 39  41.896215 -87.728572   (41.89621515, -87.728572048)
#
# [5 rows x 22 columns]

# %%
crime_data.shape
# Out:
# (259169, 22)

# %% [markdown]
# Note that the crime data contains all incidents that occured between 01 Jan 2019 to 31st Dec 2019.

# %%
print(min(crime_data.Date), max(crime_data.Date))
# Out:
# 2019-01-01 00:00:00 2019-12-31 23:55:00

# %% [markdown]
# cleanig the data

# %%
crime_data.groupby(['Primary Type'])['ID'].count()
# Out:
# Primary Type
# ARSON                                  374
# ASSAULT                              20601
# BATTERY                              49474
# BURGLARY                              9633
# CONCEALED CARRY LICENSE VIOLATION      217
# CRIM SEXUAL ASSAULT                    908
# CRIMINAL DAMAGE                      26611
# CRIMINAL SEXUAL ASSAULT                676
# CRIMINAL TRESPASS                     6805
# DECEPTIVE PRACTICE                   18236
# GAMBLING                               142
# HOMICIDE                               508
# HUMAN TRAFFICKING                       13
# INTERFERENCE WITH PUBLIC OFFICER      1544
# INTIMIDATION                           163
# KIDNAPPING                             172
# LIQUOR LAW VIOLATION                   232
# MOTOR VEHICLE THEFT                   8962
# NARCOTICS                            14996
# NON-CRIMINAL                             4
# OBSCENITY                               59
# OFFENSE INVOLVING CHILDREN            2349
# OTHER NARCOTIC VIOLATION                 6
# OTHER OFFENSE                        16727
# PROSTITUTION                           680
# PUBLIC INDECENCY                        11
# PUBLIC PEACE VIOLATION                1518
# ROBBERY                               7989
# SEX OFFENSE                           1318
# STALKING                               224
# THEFT                                61679
# WEAPONS VIOLATION                     6338
# Name: ID, dtype: int64

# %%
crime_data.loc[crime_data['Primary Type'] == 'CRIM SEXUAL ASSAULT', 'Primary Type'] = 'CRIMINAL SEXUAL ASSAULT'

# %% [markdown]
# ### mapping for Chicago Neighborhoods and their Latitude and Longitude Boundaries

# %%
chicago_neighborhoods = pd.read_csv('IL-Regions.csv', sep='\t', header = None)

# %%
chicago_neighborhoods.head()
# Out:
#     0     1        2                3       4    5  \
# 0  IL  Cook  Chicago          Chatham  273222  218
# 1  IL  Cook  Chicago     North Center  269600  163
# 2  IL  Cook  Chicago           O'hare  269603  303
# 3  IL  Cook  Chicago  Washington Park  275927  103
# 4  IL  Cook  Chicago   Garfield Ridge  269584  271
#
#                                                    6
# 0  -87.597208915594;41.751072022231,-87.597240915...
# 1  -87.673960915665;41.961532022427,-87.673918915...
# 2  -87.836540915817;41.974888022439,-87.836540915...
# 3  -87.615601915611;41.783765022261,-87.615566915...
# 4  -87.738570915725;41.822185022297,-87.738576915...

# %%
chicago_neighborhoods.columns = ['state', 'county','city', 'neighbourhood','regionid', 'total_potins', 'coordinates']

# %%
chicago_neighborhoods['coordinates2'] = chicago_neighborhoods['coordinates'].apply(lambda x: [[float(coord.split(';')[0]), float(coord.split(';')[1])] for coord in x.split(',')])

# %%
chicago_hoods = {x:y for x, y in zip(chicago_neighborhoods['regionid'], chicago_neighborhoods['coordinates2'])}
chicago_region_ids = {x:y for x, y in zip(chicago_neighborhoods['regionid'], chicago_neighborhoods['neighbourhood'])}

# %% [markdown]
# ### Adding Neighborhood information to the Crime Dataset
#
# We the use the methodolgy given in [Craig M. Booth's github code](https://github.com/craigmbooth/chicago_neighborhood_finder/tree/739deff8f9f349720299b193b4259aa690876e52) to map the latitude-longitude data to the neighborhoods in the Zillow dataset.

# %%
def point_inside_polygon(x,y,poly):
    """Return True if the point described by x, y is inside of the polygon
    described by the list of points [(x0, y0), (x1, y1), ... (xn, yn)] in
    ``poly``
    Code from http://www.ariel.com.au/a/python-point-int-poly.html which
    in turn was adapted from C code found at
    http://local.wasp.uwa.edu.au/~pbourke/geometry/insidepoly/
    """
    n = len(poly)
    inside =False

    p1x,p1y = poly[0]
    for i in range(n+1):
        p2x,p2y = poly[i % n]
        if y > min(p1y,p2y):
            if y <= max(p1y,p2y):
                if x <= max(p1x,p2x):
                    if p1y != p2y:
                        xinters = (y-p1y)*(p2x-p1x)/(p2y-p1y)+p1x
                    if p1x == p2x or x <= xinters:
                        inside = not inside
        p1x,p1y = p2x,p2y

    return inside

# %% [markdown]
# As an example we find the neighborhood for a random coordinate point (-87.706665329, 41.800781216) and see that we obtain 'Gage Park' as the corresponding neighborhood.

# %%
chicago_region_ids[[e for i,e in enumerate(chicago_hoods.keys()) if point_inside_polygon(-87.706665329, 41.800781216, chicago_hoods[e])][0]]
# Out:
# 'Gage Park'

# %% [markdown]
# For each crime incident in the crime dataset we obtain the corresponding Zillow regionid in a column.

# %%
def addNeighToDataset(data):
    longitude = data['Longitude'].values
    latitude = data['Latitude'].values
    region = []
    for locationx, locationy in zip(longitude,latitude):
        place = [e for i,e in enumerate(chicago_hoods.keys()) if point_inside_polygon(float(locationx), float(locationy), chicago_hoods[e])]
        if len(place) == 1:
            region.append(place[0])
        else:
            region.append(None)

    data['regionid'] = region
    return data

# %%
crime_data_with_region = addNeighToDataset(crime_data)

# %%
crime_data_with_region = crime_data_with_region[crime_data_with_region.regionid.notnull()].reset_index(drop = True)
crime_data_with_region['neighborhood'] = crime_data_with_region['regionid'].apply(lambda x: chicago_region_ids[x])

# %%
crime_data_with_region['Date'] = pd.to_datetime(crime_data_with_region.Date)

# %%
crime_data_with_region.head(5)
# Out:
#          ID Case Number                Date                Block  IUCR  \
# 0  12098557    JD288415 2019-02-01 00:01:00      025XX W 50TH ST  0460
# 1  12082526    JD269406 2019-09-24 12:00:00  050XX N KENMORE AVE  1153
# 2  11859264    JC470909 2019-10-13 06:40:00   012XX S KARLOV AVE  1310
# 3  11662417    JC232642 2019-04-21 12:30:00      009XX E 80TH ST  031A
# 4  12990873    JG161829 2019-08-17 13:14:00   008XX N KARLOV AVE  1751
#
#                  Primary Type                             Description  \
# 0                     BATTERY                                  SIMPLE
# 1          DECEPTIVE PRACTICE     FINANCIAL IDENTITY THEFT OVER $ 300
# 2             CRIMINAL DAMAGE                             TO PROPERTY
# 3                     ROBBERY                         ARMED - HANDGUN
# 4  OFFENSE INVOLVING CHILDREN  CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
#
#   Location Description  Arrest  Domestic  ...  FBI Code  X Coordinate  \
# 0            RESIDENCE   False      True  ...       08B     1160373.0
# 1            RESIDENCE   False     False  ...        11     1168334.0
# 2            APARTMENT   False      True  ...        14     1149246.0
# 3            RESIDENCE   False     False  ...        03     1184044.0
# 4            RESIDENCE    True      True  ...        17     1148899.0
#
#    Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 0     1871438.0  2019  07/09/2020 03:44:39 PM  41.802925 -87.687367
# 1     1933969.0  2019  06/24/2020 03:40:28 PM  41.974346 -87.656361
# 2     1894056.0  2019  10/20/2019 07:09:58 PM  41.865214 -87.727590
# 3     1852159.0  2019  09/14/2023 03:41:59 PM  41.749500 -87.601157
# 4     1905351.0  2019  09/14/2023 03:41:59 PM  41.896215 -87.728572
#
#                         Location  regionid    neighborhood
# 0  (41.802924631, -87.687367104)  269582.0       Gage Park
# 1  (41.974346203, -87.656361214)  269609.0          Uptown
# 2  (41.865213688, -87.727590376)  269601.0  North Lawndale
# 3    (41.749500329, -87.6011574)  273222.0         Chatham
# 4   (41.89621515, -87.728572048)  269585.0   Humboldt Park
#
# [5 rows x 24 columns]

# %%
crime_data_with_region = crime_data_with_region[['ID', 'Case Number', 'Date', 'Primary Type', 'Description', 'Location Description', 'Arrest', 'Domestic', 'Year', 'regionid', 'neighborhood']]

# %% [markdown]
# We save the final crime dataset that contains the neighborhood information as a csv `crime_data_with_neighbourhoods.csv`.

# %%
crime_data_with_region.to_csv('crime_data_with_neighbourhood.csv', index = False)

# %% [markdown]
# ### Obtaining Crime Rates for Neighborhoods (based on population)

# %%
population_data = pd.read_csv('chicago_population_data.csv', sep = ',', header = 0)

# %%
population_data = population_data[['GEOG', '2010_POP']]
population_data.head()
# Out:
#              GEOG  2010_POP
# 0     Albany Park     51542
# 1  Archer Heights     13393
# 2   Armour Square     13391
# 3         Ashburn     41081
# 4  Auburn Gresham     48743

# %% [markdown]
# Next we join the population and crime dataset on the neighborhood names. We find that there are a few discrepencies between the two datasets which we can fix manually.

# %%
pop_hoods = list(population_data.GEOG.unique())
crime_hoods = list(crime_data_with_region.neighborhood.unique())

# %%
for n in pop_hoods:
    if n not in crime_hoods:
        print(n)
# Out:
# Greater Grand Crossing
# O'Hare
# Portage Park
# The Loop

# %%
for n in crime_hoods:
    if n not in pop_hoods:
        print(n)
# Out:
# Grand Crossing
# Pottage Park
# Loop
# O'hare

# %%
population_data.loc[population_data['GEOG']=='The Loop', 'GEOG'] = 'Loop'
population_data.loc[population_data['GEOG']=='Greater Grand Crossing', 'GEOG'] = 'Grand Crossing'
population_data.loc[population_data['GEOG']=='O\'Hare', 'GEOG'] = 'O\'hare'
population_data.loc[population_data['GEOG']=='Portage Park', 'GEOG'] = 'Pottage Park'

# %%
crime_with_pop = pd.merge(crime_data_with_region, population_data, left_on = 'neighborhood', right_on = 'GEOG', how = 'inner')
crime_with_pop = crime_with_pop.drop(columns = ['GEOG'])
crime_with_pop = crime_with_pop.rename(columns = {'2010_POP': 'population'})
crime_with_pop.head(5)
# Out:
#          ID Case Number                Date       Primary Type  \
# 0  12098557    JD288415 2019-02-01 00:01:00            BATTERY
# 1  12073110    JD258449 2019-11-01 08:00:00           BURGLARY
# 2  12079127    JD265413 2019-04-01 22:20:00        SEX OFFENSE
# 3  11715936    JC298110 2019-06-08 19:45:00  CRIMINAL TRESPASS
# 4  11724588    JC308202 2019-06-15 21:06:00            BATTERY
#
#                         Description                   Location Description  \
# 0                            SIMPLE                              RESIDENCE
# 1                    UNLAWFUL ENTRY  CHURCH / SYNAGOGUE / PLACE OF WORSHIP
# 2  AGGRAVATED CRIMINAL SEXUAL ABUSE                              APARTMENT
# 3                        TO VEHICLE                                 STREET
# 4                            SIMPLE                             RESTAURANT
#
#    Arrest  Domestic  Year  regionid neighborhood  population
# 0   False      True  2019  269582.0    Gage Park       39894
# 1   False     False  2019  269582.0    Gage Park       39894
# 2   False     False  2019  269582.0    Gage Park       39894
# 3    True     False  2019  269582.0    Gage Park       39894
# 4   False     False  2019  269582.0    Gage Park       39894

# %% [markdown]
# The final crime data is saved  as `crime_final.csv`.

# %%
crime_with_pop.to_csv('crime_final.csv', index = False)

# %% [markdown]
# ## Housing data analysis

# %%
zhvi_data = pd.read_csv('zillow_zhvi_neighborhood_dataset.csv', sep = ',', header = 0)

# %%
zhvi_data = zhvi_data[zhvi_data['City'] == 'Chicago'].reset_index(drop = True)

# %%
zhvi_filtered = zhvi_data[zhvi_data['RegionID'].isin(chicago_region_ids.keys())].reset_index(drop = True)

# %%
zhvi_filtered.head(5)
# Out:
#    RegionID  SizeRank    RegionName    RegionType StateName State     City  \
# 0    269592        53  Logan Square  Neighborhood        IL    IL  Chicago
# 1    269566       154   Albany Park  Neighborhood        IL    IL  Chicago
# 2    269609       159        Uptown  Neighborhood        IL    IL  Chicago
# 3    269589       163     Lake View  Neighborhood        IL    IL  Chicago
# 4    269605       171   Rogers Park  Neighborhood        IL    IL  Chicago
#
#                       Metro   CountyName  1996-01-31  ...  2019-12-31  \
# 0  Chicago-Naperville-Elgin  Cook County    151456.0  ...    427048.0
# 1  Chicago-Naperville-Elgin  Cook County    134612.0  ...    340398.0
# 2  Chicago-Naperville-Elgin  Cook County    119281.0  ...    302682.0
# 3  Chicago-Naperville-Elgin  Cook County    221230.0  ...    536521.0
# 4  Chicago-Naperville-Elgin  Cook County    103821.0  ...    215315.0
#
#    2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30  \
# 0    427606.0    430001.0    433209.0    436357.0    438596.0    441558.0
# 1    340724.0    340930.0    341095.0    342050.0    343416.0    344771.0
# 2    302986.0    303869.0    304993.0    305424.0    305700.0    306121.0
# 3    536425.0    537520.0    539307.0    540502.0    541240.0    542024.0
# 4    215820.0    216498.0    217510.0    217913.0    218352.0    219027.0
#
#    2020-07-31  2020-08-31  2020-09-30
# 0    445053.0    449245.0    454323.0
# 1    347298.0    350828.0    356003.0
# 2    307510.0    309389.0    312127.0
# 3    543851.0    546650.0    550731.0
# 4    220373.0    222044.0    224347.0
#
# [5 rows x 306 columns]

# %% [markdown]
# Next we find the average ZHVI for Chicago Neighborhoods between 01 Jan 2019 to 31 Dec 2019.

# %%
zhvi_reshaped = zhvi_filtered.melt(id_vars = ['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
       'State', 'City', 'Metro', 'CountyName'])
zhvi_reshaped = zhvi_reshaped.rename(columns = {'variable': 'Date', 'value':'ZHVI'})
zhvi_reshaped['Date'] = pd.to_datetime(zhvi_reshaped['Date'])
zhvi_reshaped = zhvi_reshaped[(zhvi_reshaped['Date'] >= '2019-01-01') & (zhvi_reshaped['Date'] < '2020-01-01') & zhvi_reshaped['ZHVI'].notnull()]

# %%
zhvi_reshaped.head(5)
# Out:
#        RegionID  SizeRank    RegionName    RegionType StateName State  \
# 18216    269592        53  Logan Square  Neighborhood        IL    IL
# 18217    269566       154   Albany Park  Neighborhood        IL    IL
# 18218    269609       159        Uptown  Neighborhood        IL    IL
# 18219    269589       163     Lake View  Neighborhood        IL    IL
# 18220    269605       171   Rogers Park  Neighborhood        IL    IL
#
#           City                     Metro   CountyName       Date      ZHVI
# 18216  Chicago  Chicago-Naperville-Elgin  Cook County 2019-01-31  430709.0
# 18217  Chicago  Chicago-Naperville-Elgin  Cook County 2019-01-31  346712.0
# 18218  Chicago  Chicago-Naperville-Elgin  Cook County 2019-01-31  301934.0
# 18219  Chicago  Chicago-Naperville-Elgin  Cook County 2019-01-31  546449.0
# 18220  Chicago  Chicago-Naperville-Elgin  Cook County 2019-01-31  216135.0

# %%
zhvi_final = zhvi_reshaped.groupby(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
       'State', 'City', 'Metro', 'CountyName']).mean().reset_index()
zhvi_final = zhvi_final.drop(columns=['SizeRank', 'RegionType', 'StateName', 'State','Metro', 'CountyName'])
zhvi_final.head(5)
# Out:
# C:\Users\AHMED\AppData\Local\Temp\ipykernel_11212\2374299047.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   'State', 'City', 'Metro', 'CountyName']).mean().reset_index()
#    RegionID RegionName     City           ZHVI
# 0    137634   Burnside  Chicago  139033.833333
# 1    137841   Clearing  Chicago  246129.833333
# 2    138129    Dunning  Chicago  294552.416667
# 3    138166  East Side  Chicago  132832.333333
# 4    138261  Englewood  Chicago   53393.166667

# %% [markdown]
# The final housing data is saved as `housing_zhvi_final.csv`.

# %%
zhvi_final.to_csv('housing_zhvi_final.csv', index = False)

# %% [markdown]
# Merging the crime and housing data analysis final

# %%
final_data = pd.merge(crime_with_pop, zhvi_final, left_on = 'regionid', right_on = 'RegionID',  how = 'inner')
final_data = final_data.drop(columns = ['regionid', 'neighborhood'])
final_data.head(5)
# Out:
#          ID Case Number                Date       Primary Type  \
# 0  12098557    JD288415 2019-02-01 00:01:00            BATTERY
# 1  12073110    JD258449 2019-11-01 08:00:00           BURGLARY
# 2  12079127    JD265413 2019-04-01 22:20:00        SEX OFFENSE
# 3  11715936    JC298110 2019-06-08 19:45:00  CRIMINAL TRESPASS
# 4  11724588    JC308202 2019-06-15 21:06:00            BATTERY
#
#                         Description                   Location Description  \
# 0                            SIMPLE                              RESIDENCE
# 1                    UNLAWFUL ENTRY  CHURCH / SYNAGOGUE / PLACE OF WORSHIP
# 2  AGGRAVATED CRIMINAL SEXUAL ABUSE                              APARTMENT
# 3                        TO VEHICLE                                 STREET
# 4                            SIMPLE                             RESTAURANT
#
#    Arrest  Domestic  Year  population  RegionID RegionName     City  \
# 0   False      True  2019       39894    269582  Gage Park  Chicago
# 1   False     False  2019       39894    269582  Gage Park  Chicago
# 2   False     False  2019       39894    269582  Gage Park  Chicago
# 3    True     False  2019       39894    269582  Gage Park  Chicago
# 4   False     False  2019       39894    269582  Gage Park  Chicago
#
#             ZHVI
# 0  185517.416667
# 1  185517.416667
# 2  185517.416667
# 3  185517.416667
# 4  185517.416667

# %%
final_data.to_csv('final_data.csv', index = False)

# %% [markdown]
# ## Climate Data analysis

# %% [markdown]
# We are using major city global dataset and later we fetch chicago data from it

# %%
climate_city = pd.read_csv("GlobalLandTemperaturesByMajorCity.csv")

# %%
climate_city.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude
# 0  Côte D'Ivoire    5.63N     3.23W
# 1  Côte D'Ivoire    5.63N     3.23W
# 2  Côte D'Ivoire    5.63N     3.23W
# 3  Côte D'Ivoire    5.63N     3.23W
# 4  Côte D'Ivoire    5.63N     3.23W

# %%
unique_city = climate_state['City'].unique()

# Print the unique states
print(unique_states)
# Out:
# ['Abidjan' 'Addis Abeba' 'Ahmadabad' 'Aleppo' 'Alexandria' 'Ankara'
#  'Baghdad' 'Bangalore' 'Bangkok' 'Belo Horizonte' 'Berlin' 'Bogotá'
#  'Bombay' 'Brasília' 'Cairo' 'Calcutta' 'Cali' 'Cape Town' 'Casablanca'
#  'Changchun' 'Chengdu' 'Chicago' 'Chongqing' 'Dakar' 'Dalian'
#  'Dar Es Salaam' 'Delhi' 'Dhaka' 'Durban' 'Faisalabad' 'Fortaleza' 'Gizeh'
#  'Guangzhou' 'Harare' 'Harbin' 'Ho Chi Minh City' 'Hyderabad' 'Ibadan'
#  'Istanbul' 'Izmir' 'Jaipur' 'Jakarta' 'Jiddah' 'Jinan' 'Kabul' 'Kano'
#  'Kanpur' 'Karachi' 'Kiev' 'Kinshasa' 'Lagos' 'Lahore' 'Lakhnau' 'Lima'
#  'London' 'Los Angeles' 'Luanda' 'Madras' 'Madrid' 'Manila' 'Mashhad'
#  'Melbourne' 'Mexico' 'Mogadishu' 'Montreal' 'Moscow' 'Nagoya' 'Nagpur'
#  'Nairobi' 'Nanjing' 'New Delhi' 'New York' 'Paris' 'Peking' 'Pune'
#  'Rangoon' 'Rio De Janeiro' 'Riyadh' 'Rome' 'São Paulo' 'Saint Petersburg'
#  'Salvador' 'Santiago' 'Santo Domingo' 'Seoul' 'Shanghai' 'Shenyang'
#  'Singapore' 'Surabaya' 'Surat' 'Sydney' 'Taipei' 'Taiyuan' 'Tangshan'
#  'Tianjin' 'Tokyo' 'Toronto' 'Umm Durman' 'Wuhan' 'Xian']

# %% [markdown]
# We extract chicago city climate data from here

# %%
chicago_climate_data = climate_state[climate_state['City'] == 'Chicago']

# %%
chicago_climate_data.head(10)
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 51674  1743-11-01               5.436                          2.205  Chicago
# 51675  1743-12-01                 NaN                            NaN  Chicago
# 51676  1744-01-01                 NaN                            NaN  Chicago
# 51677  1744-02-01                 NaN                            NaN  Chicago
# 51678  1744-03-01                 NaN                            NaN  Chicago
# 51679  1744-04-01               8.766                          2.357  Chicago
# 51680  1744-05-01              11.605                          2.102  Chicago
# 51681  1744-06-01              17.965                          1.989  Chicago
# 51682  1744-07-01              21.680                          1.786  Chicago
# 51683  1744-08-01                 NaN                            NaN  Chicago
#
#              Country Latitude Longitude
# 51674  United States   42.59N    87.27W
# 51675  United States   42.59N    87.27W
# 51676  United States   42.59N    87.27W
# 51677  United States   42.59N    87.27W
# 51678  United States   42.59N    87.27W
# 51679  United States   42.59N    87.27W
# 51680  United States   42.59N    87.27W
# 51681  United States   42.59N    87.27W
# 51682  United States   42.59N    87.27W
# 51683  United States   42.59N    87.27W

# %%
chicago_climate_data.shape
# Out:
# (3239, 7)

# %%
chicago_climate_data.columns
# Out:
# Index(['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'City',
#        'Country', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
chicago_climate_data.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# City                              object
# Country                           object
# Latitude                          object
# Longitude                         object
# dtype: object

# %%
chicago_climate_data.tail(5)
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 54908  2013-05-01              13.734                          0.863  Chicago
# 54909  2013-06-01              17.913                          0.669  Chicago
# 54910  2013-07-01              21.914                          0.322  Chicago
# 54911  2013-08-01              22.230                          0.373  Chicago
# 54912  2013-09-01              19.977                          1.033  Chicago
#
#              Country Latitude Longitude
# 54908  United States   42.59N    87.27W
# 54909  United States   42.59N    87.27W
# 54910  United States   42.59N    87.27W
# 54911  United States   42.59N    87.27W
# 54912  United States   42.59N    87.27W

# %%
chicago_climate_data= chicago_climate_data.drop('Country', axis=1)

# %%
chicago_climate_data =chicago_climate_data.reindex(columns=['index', 'dt', 'day', 'month', 'year','City','AverageTemperature','AverageTemperatureUncertainty','Latitude','Longitude'])

# %%
chicago_climate_data["dt"] = pd.to_datetime(chicago_climate_data["dt"])
chicago_climate_data.reset_index(inplace=True)
chicago_climate_data['day'] = chicago_climate_data["dt"].dt.day
chicago_climate_data['month'] = chicago_climate_data["dt"].dt.month
chicago_climate_data['year'] = chicago_climate_data["dt"].dt.year
chicago_climate_data.head()
# Out:
#    level_0  index         dt  day  month  year     City  AverageTemperature  \
# 0    51674    NaN 1743-11-01    1     11  1743  Chicago               5.436
# 1    51675    NaN 1743-12-01    1     12  1743  Chicago                 NaN
# 2    51676    NaN 1744-01-01    1      1  1744  Chicago                 NaN
# 3    51677    NaN 1744-02-01    1      2  1744  Chicago                 NaN
# 4    51678    NaN 1744-03-01    1      3  1744  Chicago                 NaN
#
#    AverageTemperatureUncertainty Latitude Longitude
# 0                          2.205   42.59N    87.27W
# 1                            NaN   42.59N    87.27W
# 2                            NaN   42.59N    87.27W
# 3                            NaN   42.59N    87.27W
# 4                            NaN   42.59N    87.27W

# %%
# Drop the 'index' column in-place
chicago_climate_data.drop(columns=['index'], inplace=True)

# %%
# Rename 'level_0' as 'index' in-place
chicago_climate_data.rename(columns={'level_0': 'index'}, inplace=True)

# %%
chicago_climate_data.head(5)
# Out:
#    index         dt  day  month  year     City  AverageTemperature  \
# 0  51674 1743-11-01    1     11  1743  Chicago               5.436
# 1  51675 1743-12-01    1     12  1743  Chicago                 NaN
# 2  51676 1744-01-01    1      1  1744  Chicago                 NaN
# 3  51677 1744-02-01    1      2  1744  Chicago                 NaN
# 4  51678 1744-03-01    1      3  1744  Chicago                 NaN
#
#    AverageTemperatureUncertainty Latitude Longitude
# 0                          2.205   42.59N    87.27W
# 1                            NaN   42.59N    87.27W
# 2                            NaN   42.59N    87.27W
# 3                            NaN   42.59N    87.27W
# 4                            NaN   42.59N    87.27W

# %%
chicago_climate_data.to_csv("chicago_climate_data.csv",index=False)
